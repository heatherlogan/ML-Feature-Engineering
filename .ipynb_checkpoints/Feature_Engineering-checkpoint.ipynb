# %% [markdown]
# # Case Study 1
#
# #### Predicting Central Neuropathic Pain (CNP) in people with Spinal Cord Injury (SCI) from Electroencephalogram (EEG) data.
#
# * CNP is pain in response to non-painful stimuli, episodic (electric shock), “pins and needles”, numbness
# * There is currently no treatment, only prevention
# * Preventative medications have strong side-effects
# * Predicting whether a patient is likely to develop pain is useful for selective treatment
#
# #### Task
# Your task is to devise a feature engineering strategy which, in combination with a classifier of your choice, optizimes prediction accuracy.
#
# #### Data
# The data is preprocessed brain EEG data from SCI patients recorded while resting with eyes closed (EC) and eyes opened (EO).
# * 48 electrodes recording electrical activity of the brain at 250 Hz
# * 2 classes: subject will / will not develop neuropathic pain within 6 months
# * 18 subjects: 10 developed pain and 8 didn’t develop pain
# * the data has already undergone some preprocessing
#   * Signal denoising and normalization
#   * Temporal segmentation
#   * Frequency band power estimation
#   * Normalization with respect to total band power
#   * Features include normalized alpha, beta, theta band power while eyes closed, eyes opened, and taking the ratio of eo/ec.
# * the data is provided in a single table ('data.csv') consisting of
#   * 180 rows (18 subjects x 10 repetitions), each containing
#   * 432 columns (9 features x 48 electrodes)
#   * rows are in subject major order, i.e. rows 0-9 are all samples from subject 0, rows 10-19 all samples from subject 1, etc.
#   * columns are in feature_type major order, i.e. columns 0-47 are alpha band power, eyes closed, electrodes 0-48
#   * feature identifiers for all columns are stored in 'feature_names.csv'
#   * 'labels.csv' defines the corresponding class (0 or 1) to each row in data.csv
#
# #### Objective Measure
# Leave one subject out cross-validation accuracy, sensitivity and specificity.
#
# #### Report
# Report on your feature engineering pipeline, the classifier used to evaluate performance, and the performance as mean and standard deviation of accuracy, sensitivity and specificity across folds. Give evidence for why your strategy is better than others.

# %%
import csv
import numpy as np
import pandas as pd
import seaborn as sns

from matplotlib import pyplot as plt

# %% [markdown]
# ## Dataset

# %%
X = np.loadtxt('data.csv', delimiter=',') 
y = np.loadtxt('labels.csv', delimiter=',')
with open('feature_names.csv') as f:
    csvreader = csv.reader(f, delimiter=',')
    feature_names = [row for row in csvreader][0]

# %%
# plotting data in 2D with axes sampled 
# a) at random 
# b) from same electrode
# c) from same feature type
num_features = 9
num_electrodes = 48

# a) indices drawn at random
i0, i1 = np.random.randint(0, X.shape[1], size=2)

# b) same electrode, different feature (uncomment lines below)
#f0, f1 = np.random.randint(0, num_features, size=2)
#e = np.random.randint(0, num_electrodes)
#i0, i1 = f0*num_electrodes + e, f1*num_electrodes + e

# b) same feature, different electrode (uncomment lines below)
#f = np.random.randint(0, num_features)
#e0, e1 = np.random.randint(0, num_electrodes, size=2)
#i0, i1 = f*num_electrodes + e0, f*num_electrodes + e1

fig, axes = plt.subplots(1, 3, figsize=(24, 6))
colors = ['blue', 'red']

# select features i0, i1 and separate by class
X00, X01 = X[y==0][:,i0], X[y==1][:,i0]
X10, X11 = X[y==0][:,i1], X[y==1][:,i1]
# plot cumulative distribution of feature i0 separate for each class
axes[0].hist(X00, bins=20, label='y=0, '+ feature_names[i0], density=True, alpha=0.5)
axes[0].hist(X01, bins=20, label='y=1, '+ feature_names[i0], density=True, alpha=0.5)
axes[0].hist(X10, bins=20, label='y=0, '+ feature_names[i1], density=True, alpha=0.5)
axes[0].hist(X11, bins=20, label='y=1, '+ feature_names[i1], density=True, alpha=0.5)
axes[0].set_title('histograms')
axes[0].legend()
axes[1].plot(np.sort(X00), np.linspace(0,1,X00.shape[0]), label='y=0, '+ feature_names[i0], alpha=0.5)
axes[1].plot(np.sort(X01), np.linspace(0,1,X01.shape[0]), label='y=1, '+ feature_names[i0], alpha=0.5)
axes[1].plot(np.sort(X10), np.linspace(0,1,X10.shape[0]), label='y=0, '+ feature_names[i1], alpha=0.5)
axes[1].plot(np.sort(X11), np.linspace(0,1,X11.shape[0]), label='y=1, '+ feature_names[i1], alpha=0.5)
axes[1].set_title('empirical cumulative distribution functions')
axes[1].legend()
axes[2].scatter(X00, X10, label='y=0')
axes[2].scatter(X01, X11, label='y=1')
axes[2].set_xlabel(feature_names[i0])
axes[2].set_ylabel(feature_names[i1])
axes[2].set_title('scatter plot')
axes[2].legend()

# %%
dataframe = pd.DataFrame(X, columns=feature_names)
dataframe.head()
# Out:
#    alpha_ec_0  alpha_ec_1  alpha_ec_2  alpha_ec_3  alpha_ec_4  alpha_ec_5  \
# 0     0.11184     0.12387     0.12858     0.11324     0.10571     0.10690
# 1     0.29834     0.26881     0.26239     0.38009     0.34358     0.28500
# 2     0.36912     0.39587     0.38999     0.25772     0.40554     0.44199
# 3     0.76120     0.77726     0.77042     0.60161     0.70183     0.72725
# 4     0.16770     0.15146     0.14714     0.15728     0.14965     0.14154
#
#    alpha_ec_6  alpha_ec_7  alpha_ec_8  alpha_ec_9  ...  ratio_theta_38  \
# 0     0.10756     0.11064     0.10875     0.15893  ...         0.57161
# 1     0.24791     0.25033     0.26047     0.26016  ...         0.35142
# 2     0.44004     0.39947     0.31546     0.28348  ...         0.61924
# 3     0.76245     0.78904     0.72984     0.52236  ...         0.23456
# 4     0.13228     0.12760     0.14351     0.17252  ...         1.82160
#
#    ratio_theta_39  ratio_theta_40  ratio_theta_41  ratio_theta_42  \
# 0         0.73870         0.58709         0.55198         0.54811
# 1         0.32788         0.43164         0.49603         0.40680
# 2         0.86506         1.09310         0.31759         0.36353
# 3         0.25090         0.43196         0.71301         0.53340
# 4         1.73190         1.24420         2.76220         3.00930
#
#    ratio_theta_43  ratio_theta_44  ratio_theta_45  ratio_theta_46  \
# 0         0.57869         0.59345         0.60436         0.56294
# 1         0.31283         0.66352         0.58386         0.46658
# 2         0.50553         0.33478         0.49383         0.62363
# 3         0.28528         0.68135         0.66315         0.25250
# 4         2.43520         2.53070         2.58470         2.00770
#
#    ratio_theta_47
# 0         1.01440
# 1         0.74867
# 2         0.61417
# 3         0.85448
# 4         2.29460
#
# [5 rows x 432 columns]

# %%
results(X, y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic Regression: 0.8875
# Decision Tree: 0.7083333333333335
# Random forrest: 0.75

# %% [markdown]
# ## Normalisation

# %%
feature_names
# Out:
# ['alpha_ec_0',
#  'alpha_ec_1',
#  'alpha_ec_2',
#  'alpha_ec_3',
#  'alpha_ec_4',
#  'alpha_ec_5',
#  'alpha_ec_6',
#  'alpha_ec_7',
#  'alpha_ec_8',
#  'alpha_ec_9',
#  'alpha_ec_10',
#  'alpha_ec_11',
#  'alpha_ec_12',
#  'alpha_ec_13',
#  'alpha_ec_14',
#  'alpha_ec_15',
#  'alpha_ec_16',
#  'alpha_ec_17',
#  'alpha_ec_18',
#  'alpha_ec_19',
#  'alpha_ec_20',
#  'alpha_ec_21',
#  'alpha_ec_22',
#  'alpha_ec_23',
#  'alpha_ec_24',
#  'alpha_ec_25',
#  'alpha_ec_26',
#  'alpha_ec_27',
#  'alpha_ec_28',
#  'alpha_ec_29',
#  'alpha_ec_30',
#  'alpha_ec_31',
#  'alpha_ec_32',
#  'alpha_ec_33',
#  'alpha_ec_34',
#  'alpha_ec_35',
#  'alpha_ec_36',
#  'alpha_ec_37',
#  'alpha_ec_38',
#  'alpha_ec_39',
#  'alpha_ec_40',
#  'alpha_ec_41',
#  'alpha_ec_42',
#  'alpha_ec_43',
#  'alpha_ec_44',
#  'alpha_ec_45',
#  'alpha_ec_46',
#  'alpha_ec_47',
#  'beta_ec_0',
#  'beta_ec_1',
#  'beta_ec_2',
#  'beta_ec_3',
#  'beta_ec_4',
#  'beta_ec_5',
#  'beta_ec_6',
#  'beta_ec_7',
#  'beta_ec_8',
#  'beta_ec_9',
#  'beta_ec_10',
#  'beta_ec_11',
#  'beta_ec_12',
#  'beta_ec_13',
#  'beta_ec_14',
#  'beta_ec_15',
#  'beta_ec_16',
#  'beta_ec_17',
#  'beta_ec_18',
#  'beta_ec_19',
#  'beta_ec_20',
#  'beta_ec_21',
#  'beta_ec_22',
#  'beta_ec_23',
#  'beta_ec_24',
#  'beta_ec_25',
#  'beta_ec_26',
#  'beta_ec_27',
#  'beta_ec_28',
#  'beta_ec_29',
#  'beta_ec_30',
#  'beta_ec_31',
#  'beta_ec_32',
#  'beta_ec_33',
#  'beta_ec_34',
#  'beta_ec_35',
#  'beta_ec_36',
#  'beta_ec_37',
#  'beta_ec_38',
#  'beta_ec_39',
#  'beta_ec_40',
#  'beta_ec_41',
#  'beta_ec_42',
#  'beta_ec_43',
#  'beta_ec_44',
#  'beta_ec_45',
#  'beta_ec_46',
#  'beta_ec_47',
#  'theta_ec_0',
#  'theta_ec_1',
#  'theta_ec_2',
#  'theta_ec_3',
#  'theta_ec_4',
#  'theta_ec_5',
#  'theta_ec_6',
#  'theta_ec_7',
#  'theta_ec_8',
#  'theta_ec_9',
#  'theta_ec_10',
#  'theta_ec_11',
#  'theta_ec_12',
#  'theta_ec_13',
#  'theta_ec_14',
#  'theta_ec_15',
#  'theta_ec_16',
#  'theta_ec_17',
#  'theta_ec_18',
#  'theta_ec_19',
#  'theta_ec_20',
#  'theta_ec_21',
#  'theta_ec_22',
#  'theta_ec_23',
#  'theta_ec_24',
#  'theta_ec_25',
#  'theta_ec_26',
#  'theta_ec_27',
#  'theta_ec_28',
#  'theta_ec_29',
#  'theta_ec_30',
#  'theta_ec_31',
#  'theta_ec_32',
#  'theta_ec_33',
#  'theta_ec_34',
#  'theta_ec_35',
#  'theta_ec_36',
#  'theta_ec_37',
#  'theta_ec_38',
#  'theta_ec_39',
#  'theta_ec_40',
#  'theta_ec_41',
#  'theta_ec_42',
#  'theta_ec_43',
#  'theta_ec_44',
#  'theta_ec_45',
#  'theta_ec_46',
#  'theta_ec_47',
#  'alpha_eo_0',
#  'alpha_eo_1',
#  'alpha_eo_2',
#  'alpha_eo_3',
#  'alpha_eo_4',
#  'alpha_eo_5',
#  'alpha_eo_6',
#  'alpha_eo_7',
#  'alpha_eo_8',
#  'alpha_eo_9',
#  'alpha_eo_10',
#  'alpha_eo_11',
#  'alpha_eo_12',
#  'alpha_eo_13',
#  'alpha_eo_14',
#  'alpha_eo_15',
#  'alpha_eo_16',
#  'alpha_eo_17',
#  'alpha_eo_18',
#  'alpha_eo_19',
#  'alpha_eo_20',
#  'alpha_eo_21',
#  'alpha_eo_22',
#  'alpha_eo_23',
#  'alpha_eo_24',
#  'alpha_eo_25',
#  'alpha_eo_26',
#  'alpha_eo_27',
#  'alpha_eo_28',
#  'alpha_eo_29',
#  'alpha_eo_30',
#  'alpha_eo_31',
#  'alpha_eo_32',
#  'alpha_eo_33',
#  'alpha_eo_34',
#  'alpha_eo_35',
#  'alpha_eo_36',
#  'alpha_eo_37',
#  'alpha_eo_38',
#  'alpha_eo_39',
#  'alpha_eo_40',
#  'alpha_eo_41',
#  'alpha_eo_42',
#  'alpha_eo_43',
#  'alpha_eo_44',
#  'alpha_eo_45',
#  'alpha_eo_46',
#  'alpha_eo_47',
#  'beta_eo_0',
#  'beta_eo_1',
#  'beta_eo_2',
#  'beta_eo_3',
#  'beta_eo_4',
#  'beta_eo_5',
#  'beta_eo_6',
#  'beta_eo_7',
#  'beta_eo_8',
#  'beta_eo_9',
#  'beta_eo_10',
#  'beta_eo_11',
#  'beta_eo_12',
#  'beta_eo_13',
#  'beta_eo_14',
#  'beta_eo_15',
#  'beta_eo_16',
#  'beta_eo_17',
#  'beta_eo_18',
#  'beta_eo_19',
#  'beta_eo_20',
#  'beta_eo_21',
#  'beta_eo_22',
#  'beta_eo_23',
#  'beta_eo_24',
#  'beta_eo_25',
#  'beta_eo_26',
#  'beta_eo_27',
#  'beta_eo_28',
#  'beta_eo_29',
#  'beta_eo_30',
#  'beta_eo_31',
#  'beta_eo_32',
#  'beta_eo_33',
#  'beta_eo_34',
#  'beta_eo_35',
#  'beta_eo_36',
#  'beta_eo_37',
#  'beta_eo_38',
#  'beta_eo_39',
#  'beta_eo_40',
#  'beta_eo_41',
#  'beta_eo_42',
#  'beta_eo_43',
#  'beta_eo_44',
#  'beta_eo_45',
#  'beta_eo_46',
#  'beta_eo_47',
#  'theta_eo_0',
#  'theta_eo_1',
#  'theta_eo_2',
#  'theta_eo_3',
#  'theta_eo_4',
#  'theta_eo_5',
#  'theta_eo_6',
#  'theta_eo_7',
#  'theta_eo_8',
#  'theta_eo_9',
#  'theta_eo_10',
#  'theta_eo_11',
#  'theta_eo_12',
#  'theta_eo_13',
#  'theta_eo_14',
#  'theta_eo_15',
#  'theta_eo_16',
#  'theta_eo_17',
#  'theta_eo_18',
#  'theta_eo_19',
#  'theta_eo_20',
#  'theta_eo_21',
#  'theta_eo_22',
#  'theta_eo_23',
#  'theta_eo_24',
#  'theta_eo_25',
#  'theta_eo_26',
#  'theta_eo_27',
#  'theta_eo_28',
#  'theta_eo_29',
#  'theta_eo_30',
#  'theta_eo_31',
#  'theta_eo_32',
#  'theta_eo_33',
#  'theta_eo_34',
#  'theta_eo_35',
#  'theta_eo_36',
#  'theta_eo_37',
#  'theta_eo_38',
#  'theta_eo_39',
#  'theta_eo_40',
#  'theta_eo_41',
#  'theta_eo_42',
#  'theta_eo_43',
#  'theta_eo_44',
#  'theta_eo_45',
#  'theta_eo_46',
#  'theta_eo_47',
#  'ratio_alpha_0',
#  'ratio_alpha_1',
#  'ratio_alpha_2',
#  'ratio_alpha_3',
#  'ratio_alpha_4',
#  'ratio_alpha_5',
#  'ratio_alpha_6',
#  'ratio_alpha_7',
#  'ratio_alpha_8',
#  'ratio_alpha_9',
#  'ratio_alpha_10',
#  'ratio_alpha_11',
#  'ratio_alpha_12',
#  'ratio_alpha_13',
#  'ratio_alpha_14',
#  'ratio_alpha_15',
#  'ratio_alpha_16',
#  'ratio_alpha_17',
#  'ratio_alpha_18',
#  'ratio_alpha_19',
#  'ratio_alpha_20',
#  'ratio_alpha_21',
#  'ratio_alpha_22',
#  'ratio_alpha_23',
#  'ratio_alpha_24',
#  'ratio_alpha_25',
#  'ratio_alpha_26',
#  'ratio_alpha_27',
#  'ratio_alpha_28',
#  'ratio_alpha_29',
#  'ratio_alpha_30',
#  'ratio_alpha_31',
#  'ratio_alpha_32',
#  'ratio_alpha_33',
#  'ratio_alpha_34',
#  'ratio_alpha_35',
#  'ratio_alpha_36',
#  'ratio_alpha_37',
#  'ratio_alpha_38',
#  'ratio_alpha_39',
#  'ratio_alpha_40',
#  'ratio_alpha_41',
#  'ratio_alpha_42',
#  'ratio_alpha_43',
#  'ratio_alpha_44',
#  'ratio_alpha_45',
#  'ratio_alpha_46',
#  'ratio_alpha_47',
#  'ratio_beta_0',
#  'ratio_beta_1',
#  'ratio_beta_2',
#  'ratio_beta_3',
#  'ratio_beta_4',
#  'ratio_beta_5',
#  'ratio_beta_6',
#  'ratio_beta_7',
#  'ratio_beta_8',
#  'ratio_beta_9',
#  'ratio_beta_10',
#  'ratio_beta_11',
#  'ratio_beta_12',
#  'ratio_beta_13',
#  'ratio_beta_14',
#  'ratio_beta_15',
#  'ratio_beta_16',
#  'ratio_beta_17',
#  'ratio_beta_18',
#  'ratio_beta_19',
#  'ratio_beta_20',
#  'ratio_beta_21',
#  'ratio_beta_22',
#  'ratio_beta_23',
#  'ratio_beta_24',
#  'ratio_beta_25',
#  'ratio_beta_26',
#  'ratio_beta_27',
#  'ratio_beta_28',
#  'ratio_beta_29',
#  'ratio_beta_30',
#  'ratio_beta_31',
#  'ratio_beta_32',
#  'ratio_beta_33',
#  'ratio_beta_34',
#  'ratio_beta_35',
#  'ratio_beta_36',
#  'ratio_beta_37',
#  'ratio_beta_38',
#  'ratio_beta_39',
#  'ratio_beta_40',
#  'ratio_beta_41',
#  'ratio_beta_42',
#  'ratio_beta_43',
#  'ratio_beta_44',
#  'ratio_beta_45',
#  'ratio_beta_46',
#  'ratio_beta_47',
#  'ratio_theta_0',
#  'ratio_theta_1',
#  'ratio_theta_2',
#  'ratio_theta_3',
#  'ratio_theta_4',
#  'ratio_theta_5',
#  'ratio_theta_6',
#  'ratio_theta_7',
#  'ratio_theta_8',
#  'ratio_theta_9',
#  'ratio_theta_10',
#  'ratio_theta_11',
#  'ratio_theta_12',
#  'ratio_theta_13',
#  'ratio_theta_14',
#  'ratio_theta_15',
#  'ratio_theta_16',
#  'ratio_theta_17',
#  'ratio_theta_18',
#  'ratio_theta_19',
#  'ratio_theta_20',
#  'ratio_theta_21',
#  'ratio_theta_22',
#  'ratio_theta_23',
#  'ratio_theta_24',
#  'ratio_theta_25',
#  'ratio_theta_26',
#  'ratio_theta_27',
#  'ratio_theta_28',
#  'ratio_theta_29',
#  'ratio_theta_30',
#  'ratio_theta_31',
#  'ratio_theta_32',
#  'ratio_theta_33',
#  'ratio_theta_34',
#  'ratio_theta_35',
#  'ratio_theta_36',
#  'ratio_theta_37',
#  'ratio_theta_38',
#  'ratio_theta_39',
#  'ratio_theta_40',
#  'ratio_theta_41',
#  'ratio_theta_42',
#  'ratio_theta_43',
#  'ratio_theta_44',
#  'ratio_theta_45',
#  'ratio_theta_46',
#  'ratio_theta_47']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
data = X
scaler.fit(data)
newdata = scaler.transform(data)
pd.DataFrame(newdata, columns=feature_names).head()
# Out:
#    alpha_ec_0  alpha_ec_1  alpha_ec_2  alpha_ec_3  alpha_ec_4  alpha_ec_5  \
# 0   -1.376627   -1.355841   -1.360565   -1.282122   -1.363906   -1.363955
# 1   -0.497158   -0.659425   -0.700764    0.010004   -0.137413   -0.415607
# 2   -0.163383   -0.048920   -0.071584   -0.582529    0.182062    0.420333
# 3    1.685531    1.783604    1.804268    1.082636    1.709777    1.939286
# 4   -1.113211   -1.223275   -1.269047   -1.068874   -1.137345   -1.179503
#
#    alpha_ec_6  alpha_ec_7  alpha_ec_8  alpha_ec_9  ...  ratio_theta_38  \
# 0   -1.378199   -1.389515   -1.426743   -1.157623  ...       -0.571508
# 1   -0.622363   -0.638454   -0.619863   -0.637086  ...       -0.865352
# 2    0.412327    0.163416   -0.327414   -0.517172  ...       -0.507945
# 3    2.148622    2.257987    1.876349    0.711178  ...       -1.021302
# 4   -1.245073   -1.298327   -1.241881   -1.087742  ...        1.096609
#
#    ratio_theta_39  ratio_theta_40  ratio_theta_41  ratio_theta_42  \
# 0       -0.356933       -0.536192       -0.556666       -0.537475
# 1       -0.880993       -0.744585       -0.629078       -0.692528
# 2       -0.195742        0.142157       -0.860019       -0.740006
# 3       -0.979193       -0.744156       -0.348257       -0.553615
# 4        0.910039        0.344719        2.303849        2.163080
#
#    ratio_theta_43  ratio_theta_44  ratio_theta_45  ratio_theta_46  \
# 0       -0.503384       -0.537981       -0.551653       -0.531866
# 1       -0.843956       -0.442532       -0.578909       -0.657889
# 2       -0.597103       -0.890343       -0.698610       -0.452494
# 3       -0.879248       -0.418243       -0.473488       -0.937870
# 4        1.874839        2.100949        2.081342        1.357638
#
#    ratio_theta_47
# 0       -0.098731
# 1       -0.488323
# 2       -0.685516
# 3       -0.333193
# 4        1.778195
#
# [5 rows x 432 columns]

# %%
results(newdata, y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic Regression: 0.9249999999999999
# Decision Tree: 0.7708333333333335
# Random forrest: 0.7333333333333333

# %%
scaler = MinMaxScaler()
data = X
scaler.fit(data)
newdata = scaler.transform(data)
pd.DataFrame(newdata, columns=feature_names).head()
# Out:
#    alpha_ec_0  alpha_ec_1  alpha_ec_2  alpha_ec_3  alpha_ec_4  alpha_ec_5  \
# 0    0.070350    0.079269    0.072532    0.071386    0.062224    0.063005
# 1    0.267545    0.240236    0.223526    0.351345    0.337907    0.275265
# 2    0.342384    0.381345    0.367512    0.222964    0.409716    0.462366
# 3    0.756948    0.804906    0.796795    0.583748    0.753106    0.802340
# 4    0.129414    0.109910    0.093476    0.117589    0.113149    0.104289
#
#    alpha_ec_6  alpha_ec_7  alpha_ec_8  alpha_ec_9  ...  ratio_theta_38  \
# 0    0.059758    0.064540    0.055414    0.100919  ...        0.094498
# 1    0.230180    0.241817    0.254206    0.210730  ...        0.045912
# 2    0.463477    0.431087    0.326256    0.236026  ...        0.105008
# 3    0.854968    0.925480    0.869198    0.495153  ...        0.020126
# 4    0.089774    0.086064    0.100959    0.115661  ...        0.370315
#
#    ratio_theta_39  ratio_theta_40  ratio_theta_41  ratio_theta_42  \
# 0        0.090847        0.061854        0.091076        0.057430
# 1        0.027384        0.038127        0.078185        0.035671
# 2        0.110367        0.139086        0.037071        0.029008
# 3        0.015493        0.038176        0.128179        0.055165
# 4        0.244275        0.162149        0.600332        0.436416
#
#    ratio_theta_43  ratio_theta_44  ratio_theta_45  ratio_theta_46  \
# 0        0.082662        0.113275        0.090422        0.072849
# 1        0.033712        0.131734        0.085575        0.054201
# 2        0.069192        0.045129        0.064286        0.084594
# 3        0.028640        0.136432        0.104324        0.012772
# 4        0.424481        0.623639        0.558706        0.352440
#
#    ratio_theta_47
# 0        0.157680
# 1        0.106081
# 2        0.079964
# 3        0.126627
# 4        0.406265
#
# [5 rows x 432 columns]

# %%
results(newdata, y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic Regression: 0.8208333333333334
# Decision Tree: 0.7916666666666667
# Random forrest: 0.7291666666666667

# %%
# UNIT LENGTH
from sklearn.preprocessing import Normalizer

scaler = Normalizer()
data = X
scaler.fit(data)
newdata = scaler.transform(data)
pd.DataFrame(newdata, columns=feature_names).head()
# Out:
#    alpha_ec_0  alpha_ec_1  alpha_ec_2  alpha_ec_3  alpha_ec_4  alpha_ec_5  \
# 0    0.007201    0.007975    0.008278    0.007291    0.006806    0.006883
# 1    0.008294    0.007473    0.007294    0.010566    0.009551    0.007923
# 2    0.028684    0.030763    0.030306    0.020027    0.031515    0.034347
# 3    0.022212    0.022680    0.022481    0.017555    0.020479    0.021221
# 4    0.010058    0.009084    0.008825    0.009433    0.008976    0.008489
#
#    alpha_ec_6  alpha_ec_7  alpha_ec_8  alpha_ec_9  ...  ratio_theta_38  \
# 0    0.006925    0.007123    0.007002    0.010232  ...        0.036802
# 1    0.006892    0.006959    0.007241    0.007232  ...        0.009769
# 2    0.034196    0.031043    0.024514    0.022029  ...        0.048121
# 3    0.022248    0.023024    0.021297    0.015242  ...        0.006844
# 4    0.007934    0.007653    0.008607    0.010347  ...        0.109255
#
#    ratio_theta_39  ratio_theta_40  ratio_theta_41  ratio_theta_42  \
# 0        0.047560        0.037799        0.035538        0.035289
# 1        0.009115        0.011999        0.013789        0.011309
# 2        0.067224        0.084945        0.024680        0.028250
# 3        0.007321        0.012605        0.020805        0.015565
# 4        0.103875        0.074624        0.165670        0.180491
#
#    ratio_theta_43  ratio_theta_44  ratio_theta_45  ratio_theta_46  \
# 0        0.037258        0.038208        0.038911        0.036244
# 1        0.008696        0.018445        0.016231        0.012970
# 2        0.039285        0.026016        0.038376        0.048462
# 3        0.008324        0.019882        0.019351        0.007368
# 4        0.146058        0.151786        0.155024        0.120417
#
#    ratio_theta_47
# 0        0.065310
# 1        0.020812
# 2        0.047727
# 3        0.024934
# 4        0.137625
#
# [5 rows x 432 columns]

# %%
results(newdata, y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic Regression: 0.6416666666666667
# Decision Tree: 0.6041666666666667
# Random forrest: 0.6958333333333332

# %% [markdown]
# ## Projection

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# ### Variance threshold - increases random forrest slightly but drastically reduces features at a small cost to logistic regression: revisit with KFold CV
# ##### 432 features --> 107 features

# %%
# variance threshold
sel = VarianceThreshold(threshold=(.8 * (1 - .8)))
data = X
newdata = sel.fit_transform(data)
results(newdata, y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic Regression: 0.8708333333333333
# Decision Tree: 0.5874999999999999
# Random forrest: 0.7708333333333335

# %% [markdown]
# ### SelectKBest

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
for i in range(X.shape[1]):
    newdata = SelectKBest(chi2, k=260).fit_transform(X, y)
    results(newdata, y)
print(X.shape, newdata.shape)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic Regression: 0.8666666666666667
# Decision Tree: 0.6708333333333334
# Random forrest: 0.7125
# (180, 432) (180, 260)

# %% [markdown]
# ## AUC Scores

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score

def log_reg(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0,stratify=y)
    lgr = LogisticRegression()
    lgr.fit(X_train,y_train)
    pred = lgr.predict(X_test)
    fpr, tpr, _ = roc_curve(y_test, pred)
    auc = roc_auc_score(y_test, pred)
#     plt.plot(fpr, tpr, label='auc='+str(auc))
#     plt.legend(loc=4)
    return auc

def decision_tree(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0,stratify=y)
    Dt = DecisionTreeClassifier()
    Dt.fit(X_train,y_train)
    pred = Dt.predict(X_test)
    fpr, tpr, _ = roc_curve(y_test, pred)
    auc = roc_auc_score(y_test, pred)
#     plt.plot(fpr, tpr, label='auc='+str(auc))
#     plt.legend(loc=4)
    return auc

def random_forrest(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0,stratify=y)
    rfc = RandomForestClassifier(n_estimators=500)
    rfc.fit(X_train,y_train)
    pred = rfc.predict(X_test)
    fpr, tpr, _ = roc_curve(y_test, pred)
    auc = roc_auc_score(y_test, pred)
    return auc 


def results(X,y):
    print("Logistic regression: " + str(log_reg(X,y)))
    print("Decision Tree"+str(decision_tree(X,y)))
    print("Random Forrest"+ str(random_forrest(X,y)))
